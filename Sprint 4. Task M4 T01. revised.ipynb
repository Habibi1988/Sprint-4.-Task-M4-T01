# %% [markdown]
# # Mustafa Habibi
# ## Task M4 T01
# ## Exercise 1
# Download the attached dataset rent price by quarter and neighborhood.csv extracted from the OpenDataBCN website and summarize it statistically and graphically.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('preu lloguer per trimestre i barri.csv') # Original data frame.

df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# 3           Sant Pere, Santa Caterina i la Ribera
# 4                                   el Fort Pienc
# ..                                            ...
# 579  Diagonal Mar i el Front Marítim del Poblenou
# 580                         el Besòs i el Maresme
# 581                       Provençals del Poblenou
# 582                      Sant Martí de Provençals
# 583                           la Verneda i la Pau
#
#                                    Lloguer_mitja   Preu
# 0              Lloguer mitjà mensual (Euros/mes)  759.2
# 1              Lloguer mitjà mensual (Euros/mes)  929.6
# 2              Lloguer mitjà mensual (Euros/mes)  808.9
# 3              Lloguer mitjà mensual (Euros/mes)  879.4
# 4              Lloguer mitjà mensual (Euros/mes)  918.0
# ..                                           ...    ...
# 579  Lloguer mitjà per superfície (Euros/m2 mes)   15.2
# 580  Lloguer mitjà per superfície (Euros/m2 mes)   10.8
# 581  Lloguer mitjà per superfície (Euros/m2 mes)   13.8
# 582  Lloguer mitjà per superfície (Euros/m2 mes)   11.7
# 583  Lloguer mitjà per superfície (Euros/m2 mes)   11.3
#
# [584 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Any               0
# Trimestre         0
# Codi_Districte    0
# Nom_Districte     0
# Codi_Barri        0
# Nom_Barri         0
# Lloguer_mitja     0
# Preu              0
# dtype: int64

# %%
# I filtered the data frame column 'Lloguer mitjà'
#  and now just (Lloguer mitjà mensual (Euros/mes)) shows.

df[df['Lloguer_mitja'].str.contains ('(Lloguer mitjà mensual)')]
# Out:
# C:\Users\mhabi\AppData\Local\Temp\ipykernel_11452\3051375510.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[df['Lloguer_mitja'].str.contains ('(Lloguer mitjà mensual)')]
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 506  2021          4              10    Sant Martí          69
# 507  2021          4              10    Sant Martí          70
# 508  2021          4              10    Sant Martí          71
# 509  2021          4              10    Sant Martí          72
# 510  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# 3           Sant Pere, Santa Caterina i la Ribera
# 4                                   el Fort Pienc
# ..                                            ...
# 506  Diagonal Mar i el Front Marítim del Poblenou
# 507                         el Besòs i el Maresme
# 508                       Provençals del Poblenou
# 509                      Sant Martí de Provençals
# 510                           la Verneda i la Pau
#
#                          Lloguer_mitja    Preu
# 0    Lloguer mitjà mensual (Euros/mes)   759.2
# 1    Lloguer mitjà mensual (Euros/mes)   929.6
# 2    Lloguer mitjà mensual (Euros/mes)   808.9
# 3    Lloguer mitjà mensual (Euros/mes)   879.4
# 4    Lloguer mitjà mensual (Euros/mes)   918.0
# ..                                 ...     ...
# 506  Lloguer mitjà mensual (Euros/mes)  1205.3
# 507  Lloguer mitjà mensual (Euros/mes)   700.5
# 508  Lloguer mitjà mensual (Euros/mes)   977.8
# 509  Lloguer mitjà mensual (Euros/mes)   826.2
# 510  Lloguer mitjà mensual (Euros/mes)   752.0
#
# [292 rows x 8 columns]

# %%
df.info() # I want to change the 'preu' column to foat.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             584 non-null    int64
#  1   Trimestre       584 non-null    int64
#  2   Codi_Districte  584 non-null    int64
#  3   Nom_Districte   584 non-null    object
#  4   Codi_Barri      584 non-null    int64
#  5   Nom_Barri       584 non-null    object
#  6   Lloguer_mitja   584 non-null    object
#  7   Preu            584 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 36.6+ KB

# %%
df['Preu'] = df['Preu'].replace('--', np.nan) 
df['Preu'] = df['Preu'].astype(float) # changed to float.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             584 non-null    int64
#  1   Trimestre       584 non-null    int64
#  2   Codi_Districte  584 non-null    int64
#  3   Nom_Districte   584 non-null    object
#  4   Codi_Barri      584 non-null    int64
#  5   Nom_Barri       584 non-null    object
#  6   Lloguer_mitja   584 non-null    object
#  7   Preu            540 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 36.6+ KB

# %%
df.isnull().sum() # I want to replace the  null values with average by district.
# Out:
# Any                0
# Trimestre          0
# Codi_Districte     0
# Nom_Districte      0
# Codi_Barri         0
# Nom_Barri          0
# Lloguer_mitja      0
# Preu              44
# dtype: int64

# %%
# I replaced null values of 'preu' column with average by district.
# Calculate district averages

district_averages = df.groupby('Nom_Districte')['Preu'].mean()

# Create a mapping of districts to average prices
district_mapping = district_averages.to_dict()

# Impute missing values based on district averages
for index, row in df.iterrows():
    if pd.isnull(row['Preu']):
        district = row['Nom_Districte']
        df.at[index, 'Preu'] = district_mapping[district]
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# 3           Sant Pere, Santa Caterina i la Ribera
# 4                                   el Fort Pienc
# ..                                            ...
# 579  Diagonal Mar i el Front Marítim del Poblenou
# 580                         el Besòs i el Maresme
# 581                       Provençals del Poblenou
# 582                      Sant Martí de Provençals
# 583                           la Verneda i la Pau
#
#                                    Lloguer_mitja   Preu
# 0              Lloguer mitjà mensual (Euros/mes)  759.2
# 1              Lloguer mitjà mensual (Euros/mes)  929.6
# 2              Lloguer mitjà mensual (Euros/mes)  808.9
# 3              Lloguer mitjà mensual (Euros/mes)  879.4
# 4              Lloguer mitjà mensual (Euros/mes)  918.0
# ..                                           ...    ...
# 579  Lloguer mitjà per superfície (Euros/m2 mes)   15.2
# 580  Lloguer mitjà per superfície (Euros/m2 mes)   10.8
# 581  Lloguer mitjà per superfície (Euros/m2 mes)   13.8
# 582  Lloguer mitjà per superfície (Euros/m2 mes)   11.7
# 583  Lloguer mitjà per superfície (Euros/m2 mes)   11.3
#
# [584 rows x 8 columns]

# %%
df.describe().T
# Out:
#                 count         mean         std     min      25%        50%  \
# Any             584.0  2021.000000    0.000000  2021.0  2021.00  2021.0000
# Trimestre       584.0     2.500000    1.118992     1.0     1.75     2.5000
# Codi_Districte  584.0     6.246575    2.790726     1.0     4.00     7.0000
# Codi_Barri      584.0    37.000000   21.089371     1.0    19.00    37.0000
# Preu            584.0   436.107197  440.341505     6.7    12.90   337.6075
#
#                      75%     max
# Any             2021.000  2021.0
# Trimestre          3.250     4.0
# Codi_Districte     8.000    10.0
# Codi_Barri        55.000    73.0
# Preu             804.775  1816.5

# %%
df.isnull().sum()
# Out:
# Any               0
# Trimestre         0
# Codi_Districte    0
# Nom_Districte     0
# Codi_Barri        0
# Nom_Barri         0
# Lloguer_mitja     0
# Preu              0
# dtype: int64

# %% [markdown]
# ### Create at least one view for:
# - A categorical variable (District or Neighborhood)
# - A numeric variable (Price)
# - A numerical variable and a categorical one (District and Price)
# - Two numeric variables (Year or Quarter and Price)
# - Three variables (Neighbourhood or District, Quarter and Price)

# %%
# A categorical variable (District) 
df['Nom_Districte'].value_counts().plot(kind='bar')
plt.title('just district')
plt.show()

# %%
df['Preu'].describe()
# Out:
# count     584.000000
# mean      436.107197
# std       440.341505
# min         6.700000
# 25%        12.900000
# 50%       337.607500
# 75%       804.775000
# max      1816.500000
# Name: Preu, dtype: float64

# %%
# A numeric variable (Price)
sns.boxplot(data=df, x='Preu')
plt.show()

# %%
sns.barplot(data=df, x='Preu', y= 'Nom_Districte')
plt.title('price and district')
plt.show()

# %%
# I don't like to sort the price column but for better apearence, in this level I sort the price.

df.sort_values(by= 'Preu', ascending = False, inplace= True)

# %%
# once again I want to repeate this with sorted values.
sns.barplot(data=df, x='Preu', y= 'Nom_Districte')
plt.title('price and district in another way')
plt.show()

# %%
# with box plot.
sns.boxplot(data=df, x='Preu', y= 'Nom_Districte')
plt.title('price and district with boxplot')
plt.show()

# %%
# Two numeric variables (Year or Quarter and Price)

sns.histplot(data=df, x= 'Preu', y= 'Trimestre' )
plt.title('quarter and price')

plt.show()

# %%
# Three variables (Neighbourhood or District, Quarter and Price)

plt.figure(figsize=(15, 4))
sns.barplot(x='Trimestre', y='Preu', hue='Nom_Districte', data=df)
plt.xlabel('Trimestre')
plt.ylabel('Preu')
plt.title('Quarterly Prices by district')
plt.legend(title='district', bbox_to_anchor=(1, 1), loc='upper left')

plt.show()

# %% [markdown]
# ## Exercise 2
# Export graphics as images or as HTML.

# %%
# I will export all graphics as images.

# %% [markdown]
# ## Exercise 3
# Suggest a visualization that you think might be interesting.

# %%
sns.lmplot(x='Trimestre', y='Preu', hue='Nom_Districte', data=df)
plt.title('my suggested plot')
# Out:
# Text(0.5, 1.0, 'my suggested plot')
